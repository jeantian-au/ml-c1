# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def compute_cost(x, y, w,b):
    m = x.shape[0]
    cost = 0
    
    for i in range(m):
        f_wb = w*x[i] + b
        cost += (f_wb - y[i])**2
    total_cost = 1/(2*m) * cost
    return total_cost

# %%
def compute_gradient(x,y,w,b):
    m = x.shape[0]
    dj_dw = 0
    dj_db = 0
    
    for i in range(m):
        f_wb = w *x[i] + b
        dj_dw_i = (f_wb - y[i])*x[i] 
        dj_db_i = f_wb - y[i]
        dj_dw += dj_dw_i
        dj_db += dj_db_i
    dj_dw = dj_dw/m
    dj_db = dj_db/m
    return dj_dw, dj_db

# %%
def gradient_descent (x, y, w_in, b_in, alpha, num_iters, cost_function, gradient_function):
    J_history = []
    p_history = []
    b = b_in
    w = w_in

    for i in range(num_iters):
        dj_dw, dj_db = gradient_function(x, y, w, b)
        w = w - alpha * dj_dw
        b = b - alpha * dj_db

        if i <10000:
            J_history.append(cost_function(x,y,w,b))
            p_history.append([w,b])
            
    return w, b, J_history, p_history

# %%
x_train = np.array([1,2])
y_train = np.array([300, 500])
w_in = 100
b_in =100
num_iters = 3
alpha = 0.01

w, b, J_hist, p_hist = gradient_descent(x_train, y_train, w_in, b_in, alpha, num_iters, compute_cost, compute_gradient)

print(f"J_history: 1. {J_hist[0]}  2.{J_hist[1]}  3.{J_hist[2]}")
print(f"p_history[w,b]: 1.{p_hist[0]}, 2.{p_hist[1]}, 3.{p_hist[2]}")
# Out:
# J_history: 1. 11664.5625  2.10885.395853124995  3.10158.70930016519
# p_history[w,b]: 1.[np.float64(102.5), np.float64(101.5)], 2.[np.float64(104.915), np.float64(102.9475)], 3.[np.float64(107.24791250000001), np.float64(104.3443)]

# %%
x_train = np.array([1,2])
y_train = np.array([300, 500])
w_in = 100
b_in =100
num_iters = 0
alpha = 0.01

w, b, J_hist, p_hist = gradient_descent(x_train, y_train, w_in, b_in, alpha, num_iters, compute_cost, compute_gradient)
print(f"J_hist: {J_hist} & p_hist: {p_hist}")
# Out:
# J_hist: [] & p_hist: []

# %%
x_train = np.array([1,2])
y_train = np.array([300, 500])
w_in = 100
b_in =100
num_iters = 3
alpha = 0

w, b, J_hist, p_hist = gradient_descent(x_train, y_train, w_in, b_in, alpha, num_iters, compute_cost, compute_gradient)
print(f"J_hist: {J_hist} & p_hist: {p_hist}")
# Out:
# J_hist: [np.float64(12500.0), np.float64(12500.0), np.float64(12500.0)] & p_hist: [[np.float64(100.0), np.float64(100.0)], [np.float64(100.0), np.float64(100.0)], [np.float64(100.0), np.float64(100.0)]]

# %%
x_train = np.array([1,2])
y_train = np.array([300, 500])
w_in = 200
b_in = 100
alpha = 0.01
num_iters = 3
w, b, J_hist, p_hist = gradient_descent(x_train, y_train, w_in, b_in, alpha, num_iters, compute_cost, compute_gradient)
print(f"J_hist: {J_hist} & p_hist: {p_hist}")
# Out:
# J_hist: [np.float64(0.0), np.float64(0.0), np.float64(0.0)] & p_hist: [[np.float64(200.0), np.float64(100.0)], [np.float64(200.0), np.float64(100.0)], [np.float64(200.0), np.float64(100.0)]]

# %%
x_train = np.array([1,2])
y_train = np.array([300, 500])
w_in = 100
b_in = 100
num_iters = 3
alpha = 1.0
w, b, J_hist, p_hist = gradient_descent(x_train, y_train, w_in, b_in, alpha, num_iters, compute_cost, compute_gradient)
print(f"J_hist: {J_hist} & p_hist: {p_hist}")
# Out:
# J_hist: [np.float64(73125.0), np.float64(430312.5), np.float64(2534414.0625)] & p_hist: [[np.float64(350.0), np.float64(250.0)], [np.float64(-250.0), np.float64(-125.0)], [np.float64(1212.5), np.float64(775.0)]]
